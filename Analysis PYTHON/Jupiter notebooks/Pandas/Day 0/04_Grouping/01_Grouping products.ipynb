# %% [markdown]
# # Grouping products
#
# Using the data from the  **product_prices_cleaned.csv** file for provinces, do the following:
#
# 1. What was the average monthly price of each commodity?
# 1. Which product had the highest price volatility over the years?
#
# Use the **product** and **value** columns for analysis.
#
# Additionally:
#
# 1. Consider whether any more assumptions are needed for the tasks.
# 1. Why can this task be done only now, after cleaning the data? Do you think there are any more operations needed?

# %%
import pandas as pd
df = pd.read_csv(
                    '../../01_Data/product_prices_cleaned.csv', 
                    sep=';',
                    decimal=','
)

df.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value     date  \
# 0        pork ham cooked - per 1kg  21.37   2013-3
# 1                  bread - per 1kg    NaN   2018-2
# 2  barley groats sausage - per 1kg   3.55  2019-12
# 3       dressed chickens - per 1kg   6.14   2019-2
# 4    Italian head cheese - per 1kg   5.63   2002-3
#
#                           product2                          product
# 0        pork ham cooked - per 1kg        pork ham cooked - per 1kg
# 1                  bread - per 1kg                  bread - per 1kg
# 2  barley groats sausage - per 1kg  barley groats sausage - per 1kg
# 3       dressed chickens - per 1kg       dressed chickens - per 1kg
# 4    Italian head cheese - per 1kg    Italian head cheese - per 1kg

# %%
df['value'] = pd.to_numeric(df['value'], errors='coerce')

# %%
average_monthly_prices = df.groupby(['product', 'date'])['value'].mean()
average_monthly_prices
# Out:
# product                                  date
# 30% tomato concentrate - per 1kg         1999-1     3.455882
#                                          1999-10    3.157059
#                                          1999-11    3.272353
#                                          1999-12    3.031765
#                                          1999-2     3.276471
#                                                       ...
# whole pickled cucumbers 0.9l - per 1pc.  2019-5     2.254118
#                                          2019-6     2.134706
#                                          2019-7     1.823529
#                                          2019-8     2.107647
#                                          2019-9     2.145882
# Name: value, Length: 7559, dtype: float64

# %%
price_volatility = df.groupby(['product'])['value'].agg(["min", "max", "mean", "std"]).sort_values(by="std", ascending=False)
price_volatility
# Out:
#                                                     min    max       mean  \
# product
# natural chocolate plain - per 1kg                  0.00  25.96   6.063683
# boneless beef (sirloin) - per 1kg                 10.27  36.68  22.039316
# haddock fillets frozen - per 1kg                   0.00  23.03   4.846429
# beef with bone (rump steak) - per 1kg              7.40  33.05  18.092197
# Hunter's sausage dried - per 1kg                   0.00  29.82  18.433434
# fresh non-dressed trout - per 1kg                  0.00  17.81   4.125824
# 30% tomato concentrate - per 1kg                   0.00  15.59   4.019039
# salted herring, non-dressed - per 1kg              0.00  12.59   4.070728
# fresh non-dressed carp - per 1kg                   0.00   8.78   2.575275
# smoked bacon with ribs - per 1kg                   0.00  20.94  12.906772
# pork ham cooked - per 1kg                         12.33  26.91  18.179300
# pork  meat (raw bacon) - per 1kg                   6.20  16.80  10.705504
# Italian head cheese - per 1kg                      0.00  15.19   8.443114
# pork belly cooked - per 1kg                       11.61  23.64  16.198824
# buckwheat groats roasted whole - per 1kg           0.00   7.54   1.521676
# barley groats sausage - per 1kg                    2.88  10.86   6.000275
# whole pickled cucumbers 0.9l - per 1pc.            0.00   6.92   1.847271
# pork meat with bone (shoulder) - per 1kg           0.00  14.41   9.740180
# frozen carrot and pea mix - per 1kg                0.00   5.07   2.171914
# Backpacker's canned pork meat - per 300 g          0.00   4.85   1.604069
# dressed chickens - per 1kg                         0.00   8.53   5.445089
# beet sugar white, bagged - per 1kg                 0.00   3.98   1.175131
# pork  with bone (center-cut pork chop) - per 1kg   9.94  16.40  12.907855
# plain mixed bread (wheat-rye) - per 1kg            0.00   6.85   3.160745
# Masurian barley groats - per 1kg                   0.00   3.96   0.826062
# apple juice, boxed - per 1l                        0.00   3.29   0.615418
# bread - per 1kg                                    0.00   2.27   1.280588
# Poznan wheat flour, bagged - per 1kg               0.00   1.55   0.564297
# white table salt bagged - per 1kg                  0.00   0.57   0.078557
# fresh chicken eggs - per 10pcs.                    0.00   0.52   0.139762
#
#                                                        std
# product
# natural chocolate plain - per 1kg                 7.958616
# boneless beef (sirloin) - per 1kg                 7.044737
# haddock fillets frozen - per 1kg                  6.503833
# beef with bone (rump steak) - per 1kg             6.313232
# Hunter's sausage dried - per 1kg                  6.275892
# fresh non-dressed trout - per 1kg                 5.903562
# 30% tomato concentrate - per 1kg                  4.302276
# salted herring, non-dressed - per 1kg             3.830786
# fresh non-dressed carp - per 1kg                  3.410110
# smoked bacon with ribs - per 1kg                  3.206077
# pork ham cooked - per 1kg                         2.504910
# pork  meat (raw bacon) - per 1kg                  2.443126
# Italian head cheese - per 1kg                     2.283379
# pork belly cooked - per 1kg                       2.133067
# buckwheat groats roasted whole - per 1kg          2.101769
# barley groats sausage - per 1kg                   1.839426
# whole pickled cucumbers 0.9l - per 1pc.           1.536390
# pork meat with bone (shoulder) - per 1kg          1.529640
# frozen carrot and pea mix - per 1kg               1.447829
# Backpacker's canned pork meat - per 300 g         1.355548
# dressed chickens - per 1kg                        1.300202
# beet sugar white, bagged - per 1kg                1.171944
# pork  with bone (center-cut pork chop) - per 1kg  1.062031
# plain mixed bread (wheat-rye) - per 1kg           0.955716
# Masurian barley groats - per 1kg                  0.924551
# apple juice, boxed - per 1l                       0.899214
# bread - per 1kg                                   0.869275
# Poznan wheat flour, bagged - per 1kg              0.509885
# white table salt bagged - per 1kg                 0.152255
# fresh chicken eggs - per 10pcs.                   0.146288
