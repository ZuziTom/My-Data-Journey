# %% [markdown]
# # Aggregation
#
#
# Using data from file **product_prices_cleaned.csv**, aggregate the data for each product by month and determine the statistics: `min, max, median, mean, std` for prices (**value** column):
#
# 1. skip the national data in the analysis,
# 1. directly on the object from `groupby`,
# 1. write a loop that will calculate these values for individual provinces.
#
# Use the `agg` method, and aggregate the data with the `'product','date'` column to complete the exercise.

# %%
import pandas as pd

# %%
df = pd.read_csv('../../01_Data/product_prices_cleaned.csv', sep=';')
df.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value     date  \
# 0        pork ham cooked - per 1kg  21.37   2013-3
# 1                  bread - per 1kg    NaN   2018-2
# 2  barley groats sausage - per 1kg   3.55  2019-12
# 3       dressed chickens - per 1kg   6.14   2019-2
# 4    Italian head cheese - per 1kg   5.63   2002-3
#
#                           product2                          product
# 0        pork ham cooked - per 1kg        pork ham cooked - per 1kg
# 1                  bread - per 1kg                  bread - per 1kg
# 2  barley groats sausage - per 1kg  barley groats sausage - per 1kg
# 3       dressed chickens - per 1kg       dressed chickens - per 1kg
# 4    Italian head cheese - per 1kg    Italian head cheese - per 1kg

# %%
df.groupby(['product', 'province'])['value'].agg(['min', 'max', 'median', 'mean', 'std'])
# Out:
#                                                             min    max  \
# product                                 province
# 30% tomato concentrate - per 1kg        GREATER POLAND     1.14  15.59
#                                         HOLY CROSS         0.00   3.81
#                                         KUYAVIA-POMERANIA  0.00   9.57
#                                         LESSER POLAND      0.00   9.62
#                                         LOWER SILESIA      0.00   7.09
# ...                                                         ...    ...
# whole pickled cucumbers 0.9l - per 1pc. SILESIA            0.38   3.37
#                                         SUBCARPATHIA       1.72   3.92
#                                         WARMIA-MASURIA     0.00   2.11
#                                         WEST POMERANIA     0.00   2.63
#                                         ŁÓDŹ               0.00   3.44
#
#                                                            median       mean  \
# product                                 province
# 30% tomato concentrate - per 1kg        GREATER POLAND     10.230  10.357809
#                                         HOLY CROSS          0.000   0.080518
#                                         KUYAVIA-POMERANIA   0.000   1.861753
#                                         LESSER POLAND       7.410   6.177888
#                                         LOWER SILESIA       0.000   1.461315
# ...                                                           ...        ...
# whole pickled cucumbers 0.9l - per 1pc. SILESIA             2.725   2.673452
#                                         SUBCARPATHIA        2.575   2.689405
#                                         WARMIA-MASURIA      0.000   0.097262
#                                         WEST POMERANIA      0.000   0.408770
#                                         ŁÓDŹ                2.580   2.159524
#
#                                                                 std
# product                                 province
# 30% tomato concentrate - per 1kg        GREATER POLAND     2.477641
#                                         HOLY CROSS         0.435785
#                                         KUYAVIA-POMERANIA  2.809606
#                                         LESSER POLAND      3.040344
#                                         LOWER SILESIA      2.503964
# ...                                                             ...
# whole pickled cucumbers 0.9l - per 1pc. SILESIA            0.440439
#                                         SUBCARPATHIA       0.481247
#                                         WARMIA-MASURIA     0.352599
#                                         WEST POMERANIA     0.824889
#                                         ŁÓDŹ               1.155175
#
# [510 rows x 5 columns]

# %%
for i , j in df.groupby(['product', 'province']):
    aggs = j['value'].agg(['min', 'max', 'median', 'mean', 'std'])
    print(i, aggs)
# Out:
# ('30% tomato concentrate - per 1kg', 'GREATER POLAND') min        1.140000
# max       15.590000
# median    10.230000
# mean      10.357809
# std        2.477641
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'HOLY CROSS') min       0.000000
# max       3.810000
# median    0.000000
# mean      0.080518
# std       0.435785
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'KUYAVIA-POMERANIA') min       0.000000
# max       9.570000
# median    0.000000
# mean      1.861753
# std       2.809606
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'LESSER POLAND') min       0.000000
# max       9.620000
# median    7.410000
# mean      6.177888
# std       3.040344
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'LOWER SILESIA') min       0.000000
# max       7.090000
# median    0.000000
# mean      1.461315
# std       2.503964
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'LUBLIN') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'LUBUSZ') min       0.000000
# max       5.510000
# median    0.000000
# mean      0.118486
# std       0.645939
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'MASOVIA') min        0.000000
# max       12.140000
# median     8.930000
# mean       8.097689
# std        3.357030
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'PODLASKIE') min       0.000000
# max       7.590000
# median    0.000000
# mean      1.652869
# std       2.616823
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'POLAND') min        5.890000
# max       13.380000
# median     9.170000
# mean       9.203745
# std        1.914239
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'POMERANIA') min        0.000000
# max       12.340000
# median     9.190000
# mean       7.732191
# std        3.566856
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'SILESIA') min       0.000000
# max       7.730000
# median    5.720000
# mean      5.289482
# std       1.645414
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'SUBCARPATHIA') min        0.000000
# max       12.280000
# median     8.530000
# mean       7.934303
# std        3.219474
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'WARMIA-MASURIA') min       0.000000
# max       8.650000
# median    0.000000
# mean      2.722948
# std       3.604289
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'WEST POMERANIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('30% tomato concentrate - per 1kg', 'ŁÓDŹ') min       0.000000
# max       7.740000
# median    6.390000
# mean      5.632669
# std       2.213306
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'GREATER POLAND') min       0.000000
# max       3.260000
# median    2.170000
# mean      2.203135
# std       0.543951
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'HOLY CROSS') min       0.000000
# max       3.590000
# median    0.000000
# mean      0.594127
# std       1.146795
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'KUYAVIA-POMERANIA') min       0.000000
# max       3.450000
# median    0.185000
# mean      1.250675
# std       1.385646
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'LESSER POLAND') min       0.000000
# max       3.010000
# median    0.000000
# mean      0.725952
# std       1.135224
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'LOWER SILESIA') min       0.000000
# max       3.450000
# median    0.000000
# mean      0.911905
# std       1.295430
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'LUBLIN') min       0.000000
# max       4.850000
# median    3.150000
# mean      2.605159
# std       1.497530
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'LUBUSZ') min       0.000000
# max       3.240000
# median    0.000000
# mean      0.269802
# std       0.775242
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'MASOVIA') min       0.000000
# max       3.360000
# median    2.325000
# mean      2.044484
# std       0.936179
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'OPOLE') min       0.000000
# max       2.680000
# median    0.000000
# mean      0.185595
# std       0.544172
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'PODLASKIE') min       0.000000
# max       4.230000
# median    2.325000
# mean      2.463968
# std       1.031889
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'POLAND') min       0.090000
# max       3.360000
# median    2.530000
# mean      2.512460
# std       0.453917
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'POMERANIA') min       0.000000
# max       2.960000
# median    0.000000
# mean      0.926667
# std       1.156207
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'SILESIA') min       0.000000
# max       4.030000
# median    2.435000
# mean      1.889802
# std       1.355070
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'SUBCARPATHIA') min       0.000000
# max       3.210000
# median    2.690000
# mean      2.372222
# std       0.929642
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'WARMIA-MASURIA') min       1.900000
# max       3.690000
# median    2.650000
# mean      2.765714
# std       0.431627
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'WEST POMERANIA') min       0.000000
# max       3.930000
# median    0.000000
# mean      1.103135
# std       1.493308
# Name: value, dtype: float64
# ("Backpacker's canned pork meat - per 300 g", 'ŁÓDŹ') min       0.000000
# max       3.330000
# median    2.535000
# mean      2.444365
# std       0.567084
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'GREATER POLAND') min       15.120000
# max       24.110000
# median    18.725000
# mean      19.209762
# std        2.130595
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'HOLY CROSS') min        0.000000
# max       26.320000
# median    18.150000
# mean      12.305635
# std       10.158576
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'KUYAVIA-POMERANIA') min        0.000000
# max       26.010000
# median    20.925000
# mean      19.539405
# std        4.608469
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'LESSER POLAND') min        0.000000
# max       26.170000
# median    20.100000
# mean      19.095000
# std        6.260989
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'LOWER SILESIA') min       14.530000
# max       26.300000
# median    20.085000
# mean      20.095238
# std        2.974020
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'LUBLIN') min       14.680000
# max       27.000000
# median    19.400000
# mean      19.861389
# std        3.037419
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'LUBUSZ') min       14.880000
# max       22.990000
# median    18.285000
# mean      18.509325
# std        1.914019
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'MASOVIA') min       17.290000
# max       29.820000
# median    21.750000
# mean      22.085556
# std        3.186424
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'OPOLE') min        3.020000
# max       25.540000
# median    18.960000
# mean      19.293571
# std        3.172431
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'PODLASKIE') min       15.430000
# max       26.630000
# median    22.075000
# mean      21.580714
# std        2.684864
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'POLAND') min       16.130000
# max       25.980000
# median    19.790000
# mean      20.179325
# std        2.332816
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'POMERANIA') min       15.320000
# max       27.710000
# median    22.060000
# mean      22.230397
# std        2.567471
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'SILESIA') min        0.610000
# max       25.480000
# median    17.825000
# mean      18.401667
# std        4.194946
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'SUBCARPATHIA') min        0.000000
# max       14.170000
# median     0.000000
# mean       0.914802
# std        2.806055
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'WARMIA-MASURIA') min       15.640000
# max       25.300000
# median    20.025000
# mean      20.232897
# std        1.788794
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'WEST POMERANIA') min       16.560000
# max       25.090000
# median    20.020000
# mean      20.227897
# std        2.236255
# Name: value, dtype: float64
# ("Hunter's sausage dried - per 1kg", 'ŁÓDŹ') min       14.420000
# max       24.990000
# median    20.345000
# mean      19.605794
# std        2.577817
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'GREATER POLAND') min        5.560000
# max       11.440000
# median     7.965000
# mean       8.272698
# std        1.680842
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'HOLY CROSS') min        5.140000
# max       11.790000
# median     7.970000
# mean       8.178968
# std        1.929210
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'KUYAVIA-POMERANIA') min        5.530000
# max       12.230000
# median     7.470000
# mean       8.205992
# std        1.891518
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'LESSER POLAND') min        4.540000
# max       11.560000
# median     7.220000
# mean       7.780159
# std        2.227210
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'LOWER SILESIA') min        5.430000
# max       14.420000
# median     7.980000
# mean       8.894841
# std        2.508744
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'LUBLIN') min        4.920000
# max       11.390000
# median     7.785000
# mean       7.812659
# std        1.945921
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'LUBUSZ') min        4.940000
# max       12.800000
# median     7.720000
# mean       8.394484
# std        2.330915
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'MASOVIA') min        5.490000
# max       13.220000
# median     9.050000
# mean       9.087540
# std        2.377965
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'OPOLE') min        5.550000
# max       15.190000
# median     8.745000
# mean       9.156349
# std        2.539539
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'PODLASKIE') min        4.840000
# max       11.360000
# median     8.215000
# mean       8.154206
# std        1.773929
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'POLAND') min        5.470000
# max       12.840000
# median     7.925000
# mean       8.407262
# std        2.150464
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'POMERANIA') min        4.800000
# max       13.730000
# median     8.655000
# mean       8.787579
# std        2.527452
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'SILESIA') min        5.420000
# max       14.320000
# median     8.165000
# mean       9.005079
# std        2.584923
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'SUBCARPATHIA') min        5.270000
# max       14.300000
# median     8.285000
# mean       8.956627
# std        2.678957
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'WARMIA-MASURIA') min        0.000000
# max       12.890000
# median     7.050000
# mean       7.518135
# std        2.422202
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'WEST POMERANIA') min        5.110000
# max       11.990000
# median     7.490000
# mean       8.107579
# std        2.081811
# Name: value, dtype: float64
# ('Italian head cheese - per 1kg', 'ŁÓDŹ') min        5.460000
# max       12.820000
# median     8.925000
# mean       8.812778
# std        2.004809
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'GREATER POLAND') min       0.000000
# max       3.960000
# median    0.325000
# mean      1.311667
# std       1.521947
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'HOLY CROSS') min       1.010000
# max       2.160000
# median    1.595000
# mean      1.577024
# std       0.278465
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'KUYAVIA-POMERANIA') min       0.000000
# max       3.640000
# median    0.955000
# mean      1.086468
# std       1.204970
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'LESSER POLAND') min       0.000000
# max       1.900000
# median    1.380000
# mean      1.021151
# std       0.704232
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'LOWER SILESIA') min       0.000000
# max       1.240000
# median    0.000000
# mean      0.195556
# std       0.390044
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'LUBLIN') min       0.000000
# max       3.010000
# median    1.915000
# mean      1.597937
# std       0.875268
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'LUBUSZ') min       0.000000
# max       1.130000
# median    0.000000
# mean      0.072381
# std       0.217960
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'MASOVIA') min       0.000000
# max       3.310000
# median    1.270000
# mean      1.289405
# std       0.910538
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'PODLASKIE') min       1.010000
# max       2.380000
# median    1.345000
# mean      1.503651
# std       0.366588
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'POLAND') min       0.980000
# max       2.360000
# median    1.415000
# mean      1.557421
# std       0.384636
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'POMERANIA') min       0.000000
# max       1.730000
# median    1.210000
# mean      1.000397
# std       0.607180
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'SILESIA') min       0.000000
# max       1.000000
# median    0.000000
# mean      0.029762
# std       0.151313
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'SUBCARPATHIA') min       0.000000
# max       0.880000
# median    0.000000
# mean      0.022302
# std       0.115859
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'WARMIA-MASURIA') min       0.000000
# max       1.440000
# median    0.000000
# mean      0.095754
# std       0.311688
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'WEST POMERANIA') min       0.890000
# max       2.520000
# median    1.610000
# mean      1.603690
# std       0.446761
# Name: value, dtype: float64
# ('Masurian barley groats - per 1kg', 'ŁÓDŹ') min       0.000000
# max       1.190000
# median    0.000000
# mean      0.078492
# std       0.265551
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'GREATER POLAND') min       0.000000
# max       1.440000
# median    0.930000
# mean      0.833056
# std       0.413667
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'HOLY CROSS') min       0.000000
# max       1.520000
# median    0.835000
# mean      0.585159
# std       0.553655
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'KUYAVIA-POMERANIA') min       0.000000
# max       1.280000
# median    0.405000
# mean      0.461429
# std       0.456726
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'LESSER POLAND') min       0.710000
# max       1.550000
# median    1.050000
# mean      1.079484
# std       0.178037
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'LOWER SILESIA') min       0.000000
# max       1.350000
# median    0.610000
# mean      0.535913
# std       0.490275
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'LUBLIN') min       0.000000
# max       1.530000
# median    1.000000
# mean      0.992222
# std       0.224588
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'LUBUSZ') min       0.000000
# max       1.170000
# median    0.000000
# mean      0.334881
# std       0.411877
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'MASOVIA') min       0.000000
# max       1.110000
# median    0.000000
# mean      0.197063
# std       0.370166
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'OPOLE') min       0.000000
# max       0.990000
# median    0.000000
# mean      0.058175
# std       0.184334
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'PODLASKIE') min       0.000000
# max       0.760000
# median    0.000000
# mean      0.019048
# std       0.095065
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'POLAND') min       0.630000
# max       1.490000
# median    1.020000
# mean      1.031349
# std       0.181544
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'POMERANIA') min       0.000000
# max       1.480000
# median    0.810000
# mean      0.687302
# std       0.475759
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'SILESIA') min       0.000000
# max       1.040000
# median    0.000000
# mean      0.041984
# std       0.164099
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'SUBCARPATHIA') min       0.000000
# max       1.500000
# median    0.910000
# mean      0.745000
# std       0.473223
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'WARMIA-MASURIA') min       0.000000
# max       1.520000
# median    1.020000
# mean      0.815794
# std       0.495003
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'WEST POMERANIA') min       0.000000
# max       1.290000
# median    0.735000
# mean      0.607381
# std       0.472809
# Name: value, dtype: float64
# ('Poznan wheat flour, bagged - per 1kg', 'ŁÓDŹ') min       0.000000
# max       1.370000
# median    0.760000
# mean      0.567817
# std       0.462840
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'GREATER POLAND') min       0.000000
# max       2.180000
# median    0.000000
# mean      0.342897
# std       0.656408
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'HOLY CROSS') min       0.000000
# max       1.960000
# median    0.000000
# mean      0.045119
# std       0.233527
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'KUYAVIA-POMERANIA') min       0.000000
# max       1.890000
# median    0.000000
# mean      0.228254
# std       0.462871
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'LESSER POLAND') min       0.000000
# max       2.210000
# median    1.700000
# mean      1.606429
# std       0.414516
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'LOWER SILESIA') min       0.000000
# max       2.610000
# median    0.000000
# mean      0.343452
# std       0.739202
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'LUBLIN') min       0.000000
# max       1.920000
# median    0.000000
# mean      0.065754
# std       0.305794
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'LUBUSZ') min       0.000000
# max       2.020000
# median    0.000000
# mean      0.040952
# std       0.225685
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'MASOVIA') min       0.680000
# max       3.290000
# median    2.355000
# mean      2.373016
# std       0.463926
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'PODLASKIE') min       0.000000
# max       2.310000
# median    0.000000
# mean      0.155675
# std       0.518578
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'POLAND') min       1.340000
# max       2.430000
# median    1.920000
# mean      1.913929
# std       0.260017
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'POMERANIA') min       0.000000
# max       2.020000
# median    0.000000
# mean      0.359683
# std       0.658144
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'SILESIA') min       0.000000
# max       2.370000
# median    1.620000
# mean      1.450714
# std       0.608337
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'SUBCARPATHIA') min       0.000000
# max       1.950000
# median    0.000000
# mean      0.051349
# std       0.265193
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'WARMIA-MASURIA') min       0.000000
# max       1.480000
# median    0.000000
# mean      0.039841
# std       0.204939
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'WEST POMERANIA') min       0.000000
# max       2.630000
# median    0.000000
# mean      0.245675
# std       0.630470
# Name: value, dtype: float64
# ('apple juice, boxed - per 1l', 'ŁÓDŹ') min       0.000000
# max       2.450000
# median    1.615000
# mean      1.199365
# std       0.916100
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'GREATER POLAND') min       3.180000
# max       9.490000
# median    5.970000
# mean      6.053611
# std       1.606136
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'HOLY CROSS') min       3.130000
# max       7.810000
# median    5.205000
# mean      5.195635
# std       1.435446
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'KUYAVIA-POMERANIA') min       3.320000
# max       8.720000
# median    5.250000
# mean      5.633095
# std       1.549525
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'LESSER POLAND') min       3.180000
# max       8.900000
# median    5.180000
# mean      5.518532
# std       1.640764
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'LOWER SILESIA') min        2.960000
# max       10.140000
# median     6.375000
# mean       6.397103
# std        2.076061
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'LUBLIN') min       3.130000
# max       9.930000
# median    5.855000
# mean      6.060992
# std       1.896406
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'LUBUSZ') min       3.350000
# max       9.670000
# median    5.785000
# mean      6.018016
# std       1.848351
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'MASOVIA') min        3.410000
# max       10.580000
# median     6.675000
# mean       6.553135
# std        2.006901
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'OPOLE') min        3.270000
# max       10.860000
# median     6.700000
# mean       6.547024
# std        2.024562
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'PODLASKIE') min        3.280000
# max       10.590000
# median     6.035000
# mean       6.571746
# std        2.093079
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'POLAND') min       3.120000
# max       9.410000
# median    6.135000
# mean      6.028651
# std       1.728102
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'POMERANIA') min       3.160000
# max       9.530000
# median    5.960000
# mean      6.079008
# std       1.787076
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'SILESIA') min        3.460000
# max       10.060000
# median     5.755000
# mean       6.106468
# std        1.756277
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'SUBCARPATHIA') min       2.880000
# max       8.200000
# median    4.850000
# mean      5.196905
# std       1.581709
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'WARMIA-MASURIA') min       3.100000
# max       9.630000
# median    6.120000
# mean      5.954167
# std       2.024321
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'WEST POMERANIA') min       3.480000
# max       9.820000
# median    5.565000
# mean      6.128056
# std       1.876081
# Name: value, dtype: float64
# ('barley groats sausage - per 1kg', 'ŁÓDŹ') min       3.470000
# max       9.100000
# median    6.155000
# mean      5.962540
# std       1.408194
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'GREATER POLAND') min        8.320000
# max       29.990000
# median    20.390000
# mean      19.776587
# std        6.883835
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'HOLY CROSS') min        7.420000
# max       24.010000
# median    16.315000
# mean      15.786548
# std        5.124175
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'KUYAVIA-POMERANIA') min        7.740000
# max       29.190000
# median    18.790000
# mean      18.552222
# std        6.483860
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'LESSER POLAND') min        8.410000
# max       24.080000
# median    17.105000
# mean      16.687976
# std        5.114256
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'LOWER SILESIA') min        8.400000
# max       27.050000
# median    16.775000
# mean      17.608452
# std        5.580668
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'LUBLIN') min        8.490000
# max       29.590000
# median    17.640000
# mean      18.376270
# std        6.547999
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'LUBUSZ') min        7.530000
# max       28.330000
# median    20.060000
# mean      18.776270
# std        6.041418
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'MASOVIA') min        8.070000
# max       27.600000
# median    18.660000
# mean      18.408571
# std        6.197930
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'OPOLE') min        8.400000
# max       29.050000
# median    18.785000
# mean      18.699563
# std        6.272928
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'PODLASKIE') min        7.420000
# max       29.220000
# median    17.285000
# mean      16.713849
# std        5.777466
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'POLAND') min        8.130000
# max       28.010000
# median    18.220000
# mean      18.134286
# std        6.248538
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'POMERANIA') min        7.400000
# max       27.480000
# median    17.305000
# mean      17.736548
# std        6.286243
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'SILESIA') min        7.760000
# max       27.770000
# median    17.375000
# mean      17.759127
# std        6.341431
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'SUBCARPATHIA') min        8.200000
# max       26.110000
# median    17.510000
# mean      17.563413
# std        5.547590
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'WARMIA-MASURIA') min        7.790000
# max       29.930000
# median    19.840000
# mean      19.441111
# std        7.380286
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'WEST POMERANIA') min        8.170000
# max       33.050000
# median    19.735000
# mean      20.450714
# std        7.862226
# Name: value, dtype: float64
# ('beef with bone (rump steak) - per 1kg', 'ŁÓDŹ') min        8.110000
# max       25.360000
# median    17.480000
# mean      17.095833
# std        5.319843
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'GREATER POLAND') min       0.000000
# max       3.220000
# median    2.180000
# mean      2.100952
# std       0.579054
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'HOLY CROSS') min       0.000000
# max       3.050000
# median    0.000000
# mean      0.822063
# std       1.087600
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'KUYAVIA-POMERANIA') min       1.460000
# max       3.750000
# median    2.310000
# mean      2.343452
# std       0.439929
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'LESSER POLAND') min       0.000000
# max       3.980000
# median    0.000000
# mean      0.856706
# std       1.288644
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'LOWER SILESIA') min       1.480000
# max       3.760000
# median    2.350000
# mean      2.359286
# std       0.475017
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'LUBLIN') min       0.000000
# max       2.870000
# median    1.315000
# mean      1.177738
# std       1.165871
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'LUBUSZ') min       0.000000
# max       2.460000
# median    0.000000
# mean      0.422897
# std       0.797586
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'MASOVIA') min       0.000000
# max       2.830000
# median    2.105000
# mean      1.541627
# std       1.064488
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'OPOLE') min       0.000000
# max       2.820000
# median    0.405000
# mean      1.078175
# std       1.136625
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'PODLASKIE') min       0.000000
# max       2.650000
# median    0.000000
# mean      0.484563
# std       0.875871
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'POLAND') min       1.480000
# max       3.570000
# median    2.290000
# mean      2.338492
# std       0.443856
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'POMERANIA') min       0.000000
# max       2.630000
# median    0.000000
# mean      0.499246
# std       0.878495
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'SILESIA') min       0.000000
# max       3.020000
# median    0.530000
# mean      1.128929
# std       1.174450
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'SUBCARPATHIA') min       0.000000
# max       2.930000
# median    0.335000
# mean      1.111429
# std       1.167926
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'WARMIA-MASURIA') min       0.000000
# max       1.790000
# median    0.000000
# mean      0.034405
# std       0.199517
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'WEST POMERANIA') min       0.000000
# max       2.770000
# median    0.000000
# mean      0.590437
# std       0.983706
# Name: value, dtype: float64
# ('beet sugar white, bagged - per 1kg', 'ŁÓDŹ') min       0.000000
# max       2.990000
# median    0.000000
# mean      1.086825
# std       1.180241
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'GREATER POLAND') min       10.660000
# max       33.440000
# median    24.585000
# mean      23.085159
# std        7.100304
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'HOLY CROSS') min       10.390000
# max       28.250000
# median    19.600000
# mean      19.591270
# std        5.750979
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'KUYAVIA-POMERANIA') min       10.280000
# max       36.530000
# median    24.200000
# mean      23.130794
# std        8.529057
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'LESSER POLAND') min       10.590000
# max       30.350000
# median    19.970000
# mean      19.975675
# std        5.991405
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'LOWER SILESIA') min       10.950000
# max       30.430000
# median    21.240000
# mean      21.456786
# std        5.946957
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'LUBLIN') min       10.710000
# max       31.660000
# median    21.890000
# mean      21.182937
# std        6.538578
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'LUBUSZ') min       10.560000
# max       36.030000
# median    23.660000
# mean      23.665556
# std        7.480072
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'MASOVIA') min       10.700000
# max       31.120000
# median    21.695000
# mean      21.252341
# std        6.426609
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'OPOLE') min       10.750000
# max       34.070000
# median    23.435000
# mean      23.574365
# std        7.655827
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'PODLASKIE') min       10.270000
# max       33.440000
# median    22.175000
# mean      22.151667
# std        7.038991
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'POLAND') min       10.620000
# max       31.900000
# median    21.930000
# mean      21.926905
# std        6.865189
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'POMERANIA') min       10.510000
# max       36.680000
# median    23.900000
# mean      24.051944
# std        8.095030
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'SILESIA') min       10.710000
# max       32.690000
# median    22.025000
# mean      21.853056
# std        7.185984
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'SUBCARPATHIA') min       10.780000
# max       32.790000
# median    21.425000
# mean      21.824444
# std        6.640136
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'WARMIA-MASURIA') min       10.610000
# max       32.000000
# median    22.290000
# mean      21.827579
# std        6.390443
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'WEST POMERANIA') min       10.800000
# max       35.800000
# median    24.115000
# mean      23.379405
# std        7.461774
# Name: value, dtype: float64
# ('boneless beef (sirloin) - per 1kg', 'ŁÓDŹ') min       10.380000
# max       31.270000
# median    21.295000
# mean      20.738492
# std        6.265091
# Name: value, dtype: float64
# ('bread - per 1kg', 'GREATER POLAND') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('bread - per 1kg', 'HOLY CROSS') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('bread - per 1kg', 'KUYAVIA-POMERANIA') min       1.82
# max       1.82
# median    1.82
# mean      1.82
# std       0.00
# Name: value, dtype: float64
# ('bread - per 1kg', 'LESSER POLAND') min       2.100000e+00
# max       2.100000e+00
# median    2.100000e+00
# mean      2.100000e+00
# std       4.638361e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'LOWER SILESIA') min       1.66
# max       1.66
# median    1.66
# mean      1.66
# std       0.00
# Name: value, dtype: float64
# ('bread - per 1kg', 'LUBLIN') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('bread - per 1kg', 'LUBUSZ') min       1.980000e+00
# max       1.980000e+00
# median    1.980000e+00
# mean      1.980000e+00
# std       2.319180e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'MASOVIA') min       2.200000e+00
# max       2.200000e+00
# median    2.200000e+00
# mean      2.200000e+00
# std       4.638361e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('bread - per 1kg', 'PODLASKIE') min       1.550000e+00
# max       1.550000e+00
# median    1.550000e+00
# mean      1.550000e+00
# std       4.638361e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'POLAND') min       1.810000e+00
# max       1.810000e+00
# median    1.810000e+00
# mean      1.810000e+00
# std       2.319180e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'POMERANIA') min       1.650000e+00
# max       1.650000e+00
# median    1.650000e+00
# mean      1.650000e+00
# std       2.319180e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'SILESIA') min       2.080000e+00
# max       2.080000e+00
# median    2.080000e+00
# mean      2.080000e+00
# std       4.638361e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'SUBCARPATHIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('bread - per 1kg', 'WARMIA-MASURIA') min       2.27
# max       2.27
# median    2.27
# mean      2.27
# std       0.00
# Name: value, dtype: float64
# ('bread - per 1kg', 'WEST POMERANIA') min       1.200000e+00
# max       1.200000e+00
# median    1.200000e+00
# mean      1.200000e+00
# std       2.319180e-16
# Name: value, dtype: float64
# ('bread - per 1kg', 'ŁÓDŹ') min       1.450000e+00
# max       1.450000e+00
# median    1.450000e+00
# mean      1.450000e+00
# std       4.638361e-16
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'GREATER POLAND') min       0.000000
# max       7.150000
# median    0.000000
# mean      2.265397
# std       2.810897
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'HOLY CROSS') min       0.000000
# max       2.890000
# median    0.000000
# mean      0.069444
# std       0.381766
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'KUYAVIA-POMERANIA') min       0.000000
# max       6.480000
# median    0.000000
# mean      0.814881
# std       1.944536
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'LESSER POLAND') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'LOWER SILESIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'LUBLIN') min       0.000000
# max       5.940000
# median    3.495000
# mean      3.411151
# std       1.181488
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'LUBUSZ') min       0.000000
# max       7.540000
# median    3.485000
# mean      2.679127
# std       2.103205
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'MASOVIA') min       0.000000
# max       7.280000
# median    3.580000
# mean      3.345754
# std       2.373872
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'PODLASKIE') min       0.070000
# max       6.330000
# median    3.105000
# mean      3.195476
# std       1.087289
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'POLAND') min       0.020000
# max       6.680000
# median    3.690000
# mean      3.879167
# std       1.150626
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'POMERANIA') min       0.000000
# max       5.530000
# median    0.000000
# mean      1.800714
# std       2.244401
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'SILESIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'SUBCARPATHIA') min       0.000000
# max       2.180000
# median    0.000000
# mean      0.048889
# std       0.278163
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'WARMIA-MASURIA') min       0.000000
# max       3.130000
# median    0.000000
# mean      0.234167
# std       0.749372
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'WEST POMERANIA') min       2.160000
# max       7.360000
# median    4.045000
# mean      4.124325
# std       1.315825
# Name: value, dtype: float64
# ('buckwheat groats roasted whole - per 1kg', 'ŁÓDŹ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'GREATER POLAND') min       4.140000
# max       7.370000
# median    5.810000
# mean      5.767262
# std       0.794920
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'HOLY CROSS') min       0.000000
# max       6.940000
# median    5.290000
# mean      4.339603
# std       2.308511
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'KUYAVIA-POMERANIA') min       3.880000
# max       6.960000
# median    5.515000
# mean      5.428611
# std       0.807998
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'LESSER POLAND') min       4.020000
# max       7.230000
# median    5.515000
# mean      5.551071
# std       0.743582
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'LOWER SILESIA') min       4.040000
# max       6.980000
# median    5.600000
# mean      5.544127
# std       0.716820
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'LUBLIN') min       3.730000
# max       8.530000
# median    6.195000
# mean      6.041032
# std       1.241936
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'LUBUSZ') min       4.260000
# max       7.370000
# median    5.865000
# mean      5.777579
# std       0.704392
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'MASOVIA') min       3.880000
# max       7.240000
# median    5.560000
# mean      5.508135
# std       0.795159
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'OPOLE') min       0.000000
# max       7.940000
# median    5.905000
# mean      4.919841
# std       2.431930
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'PODLASKIE') min       4.110000
# max       7.210000
# median    5.385000
# mean      5.465238
# std       0.668546
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'POLAND') min       4.010000
# max       7.190000
# median    5.585000
# mean      5.526944
# std       0.767528
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'POMERANIA') min       4.020000
# max       7.150000
# median    5.540000
# mean      5.568492
# std       0.742285
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'SILESIA') min       0.650000
# max       6.910000
# median    5.360000
# mean      5.237778
# std       0.913050
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'SUBCARPATHIA') min       0.000000
# max       8.030000
# median    5.635000
# mean      5.179206
# std       2.327310
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'WARMIA-MASURIA') min       3.770000
# max       6.890000
# median    5.305000
# mean      5.267976
# std       0.733293
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'WEST POMERANIA') min       3.940000
# max       8.260000
# median    6.175000
# mean      6.038333
# std       0.956155
# Name: value, dtype: float64
# ('dressed chickens - per 1kg', 'ŁÓDŹ') min       3.780000
# max       7.080000
# median    5.410000
# mean      5.405278
# std       0.817156
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'GREATER POLAND') min       0.000000
# max       0.410000
# median    0.220000
# mean      0.190476
# std       0.130716
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'HOLY CROSS') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'KUYAVIA-POMERANIA') min       0.000000
# max       0.450000
# median    0.000000
# mean      0.118095
# std       0.153873
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'LESSER POLAND') min       0.000000
# max       0.390000
# median    0.240000
# mean      0.186706
# std       0.122571
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'LOWER SILESIA') min       0.000000
# max       0.450000
# median    0.250000
# mean      0.222976
# std       0.123519
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'LUBLIN') min       0.000000
# max       0.380000
# median    0.000000
# mean      0.103492
# std       0.147523
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'LUBUSZ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'MASOVIA') min       0.000000
# max       0.430000
# median    0.285000
# mean      0.244762
# std       0.128579
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'OPOLE') min       0.000000
# max       0.410000
# median    0.280000
# mean      0.235714
# std       0.124970
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'PODLASKIE') min       0.000000
# max       0.350000
# median    0.000000
# mean      0.091032
# std       0.130279
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'POLAND') min       0.180000
# max       0.450000
# median    0.270000
# mean      0.277143
# std       0.054222
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'POMERANIA') min       0.000000
# max       0.280000
# median    0.000000
# mean      0.054246
# std       0.098352
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'SILESIA') min       0.000000
# max       0.350000
# median    0.210000
# mean      0.147063
# std       0.130549
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'SUBCARPATHIA') min       0.000000
# max       0.430000
# median    0.250000
# mean      0.207183
# std       0.124557
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'WARMIA-MASURIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'WEST POMERANIA') min       0.000000
# max       0.520000
# median    0.000000
# mean      0.144405
# std       0.187130
# Name: value, dtype: float64
# ('fresh chicken eggs - per 10pcs.', 'ŁÓDŹ') min       0.000000
# max       0.430000
# median    0.195000
# mean      0.152659
# std       0.129945
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'GREATER POLAND') min       0.000000
# max       7.770000
# median    6.820000
# mean      4.877167
# std       3.123915
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'HOLY CROSS') min       0.000000
# max       7.940000
# median    0.000000
# mean      0.905167
# std       2.076002
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'KUYAVIA-POMERANIA') min       6.060000
# max       7.550000
# median    6.870000
# mean      6.795667
# std       0.403209
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'LESSER POLAND') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'LOWER SILESIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'LUBLIN') min       0.000000
# max       7.500000
# median    6.300000
# mean      4.617500
# std       2.890794
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'LUBUSZ') min       0.000000
# max       8.170000
# median    0.265000
# mean      2.026333
# std       2.707136
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'MASOVIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'PODLASKIE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'POLAND') min       6.520000
# max       7.820000
# median    7.365000
# mean      7.335167
# std       0.372261
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'POMERANIA') min       0.000000
# max       8.780000
# median    5.295000
# mean      4.127667
# std       3.866549
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'SILESIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'SUBCARPATHIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'WARMIA-MASURIA') min       6.770000
# max       8.650000
# median    7.840000
# mean      7.805833
# std       0.454627
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'WEST POMERANIA') min       0.000000
# max       8.440000
# median    6.975000
# mean      5.289167
# std       3.160089
# Name: value, dtype: float64
# ('fresh non-dressed carp - per 1kg', 'ŁÓDŹ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed trout - per 1kg', 'GREATER POLAND') min        8.370000
# max       16.740000
# median    13.105000
# mean      12.615052
# std        2.297704
# Name: value, dtype: float64
# ('fresh non-dressed trout - per 1kg', 'HOLY CROSS') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed trout - per 1kg', 'KUYAVIA-POMERANIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed trout - per 1kg', 'LESSER POLAND') min        0.000000
# max       15.810000
# median     0.000000
# mean       5.748385
# std        6.170890
# Name: value, dtype: float64
# ('fresh non-dressed trout - per 1kg', 'LOWER SILESIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('fresh non-dressed trout - per 1kg', 'LUBLIN') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# ...
# Name: value, dtype: float64
# ('pork ham cooked - per 1kg', 'POMERANIA') min       14.680000
# max       22.560000
# median    18.955000
# mean      18.575119
# std        2.129316
# Name: value, dtype: float64
# ('pork ham cooked - per 1kg', 'SILESIA') min       14.430000
# max       22.260000
# median    18.070000
# mean      17.955238
# std        2.180257
# Name: value, dtype: float64
# ('pork ham cooked - per 1kg', 'SUBCARPATHIA') min       14.180000
# max       23.700000
# median    16.540000
# mean      17.670635
# std        2.543541
# Name: value, dtype: float64
# ('pork ham cooked - per 1kg', 'WARMIA-MASURIA') min       14.630000
# max       26.100000
# median    18.985000
# mean      18.879802
# std        2.650077
# Name: value, dtype: float64
# ('pork ham cooked - per 1kg', 'WEST POMERANIA') min       15.120000
# max       24.150000
# median    18.450000
# mean      19.273452
# std        2.371426
# Name: value, dtype: float64
# ('pork ham cooked - per 1kg', 'ŁÓDŹ') min       14.150000
# max       22.680000
# median    16.955000
# mean      17.399444
# std        1.997660
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'GREATER POLAND') min        7.180000
# max       10.980000
# median     9.195000
# mean       9.097937
# std        0.760070
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'HOLY CROSS') min        7.150000
# max       13.590000
# median    10.445000
# mean      10.337540
# std        1.654398
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'KUYAVIA-POMERANIA') min        6.680000
# max       12.470000
# median     9.470000
# mean       9.473016
# std        1.513484
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'LESSER POLAND') min        7.350000
# max       11.800000
# median     9.970000
# mean       9.758214
# std        0.865239
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'LOWER SILESIA') min        8.180000
# max       12.420000
# median    10.220000
# mean      10.228968
# std        0.964656
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'LUBLIN') min        7.560000
# max       12.040000
# median     9.200000
# mean       9.448135
# std        1.037472
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'LUBUSZ') min        0.000000
# max       13.390000
# median    10.210000
# mean       9.479087
# std        3.233183
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'MASOVIA') min        6.990000
# max       11.740000
# median     8.695000
# mean       8.782976
# std        0.869503
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'OPOLE') min        0.000000
# max       14.410000
# median    11.330000
# mean      10.793571
# std        2.421409
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'PODLASKIE') min        7.020000
# max       12.660000
# median    10.150000
# mean       9.963849
# std        1.127151
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'POLAND') min        7.410000
# max       12.130000
# median     9.570000
# mean       9.559444
# std        1.068086
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'POMERANIA') min        7.180000
# max       12.700000
# median     9.660000
# mean       9.768532
# std        1.093444
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'SILESIA') min        7.760000
# max       12.280000
# median     9.680000
# mean       9.767976
# std        1.022429
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'SUBCARPATHIA') min        8.150000
# max       13.050000
# median    10.495000
# mean      10.653611
# std        1.120529
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'WARMIA-MASURIA') min        7.410000
# max       11.830000
# median     9.150000
# mean       9.386667
# std        1.144081
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'WEST POMERANIA') min        7.710000
# max       12.150000
# median     9.835000
# mean      10.009603
# std        1.110661
# Name: value, dtype: float64
# ('pork meat with bone (shoulder) - per 1kg', 'ŁÓDŹ') min        6.920000
# max       11.600000
# median     8.900000
# mean       9.073929
# std        1.096899
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'GREATER POLAND') min       0.000000
# max       9.040000
# median    4.285000
# mean      3.949008
# std       3.451789
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'HOLY CROSS') min       0.000000
# max       5.830000
# median    0.000000
# mean      0.844762
# std       1.676465
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'KUYAVIA-POMERANIA') min        0.000000
# max       10.540000
# median     5.985000
# mean       5.395079
# std        4.008516
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'LESSER POLAND') min        0.000000
# max       12.130000
# median     0.000000
# mean       3.715873
# std        4.596851
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'LOWER SILESIA') min       0.000000
# max       9.630000
# median    5.455000
# mean      4.223294
# std       3.109302
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'LUBLIN') min        0.000000
# max       10.640000
# median     4.005000
# mean       4.307421
# std        4.132369
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'LUBUSZ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'MASOVIA') min       0.000000
# max       9.520000
# median    5.515000
# mean      5.008492
# std       3.074176
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'PODLASKIE') min       0.000000
# max       8.670000
# median    4.750000
# mean      3.847302
# std       3.097626
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'POLAND') min        3.770000
# max       12.200000
# median     6.440000
# mean       7.422063
# std        2.261307
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'POMERANIA') min       0.090000
# max       9.730000
# median    6.875000
# mean      6.864960
# std       1.721059
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'SILESIA') min        0.000000
# max       10.280000
# median     6.385000
# mean       5.215437
# std        3.685993
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'SUBCARPATHIA') min       0.000000
# max       8.240000
# median    0.000000
# mean      0.733175
# std       2.079361
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'WARMIA-MASURIA') min       0.000000
# max       9.870000
# median    6.405000
# mean      5.430317
# std       3.336813
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'WEST POMERANIA') min        0.000000
# max       12.590000
# median     6.765000
# mean       7.174484
# std        3.266069
# Name: value, dtype: float64
# ('salted herring, non-dressed - per 1kg', 'ŁÓDŹ') min       0.000000
# max       9.910000
# median    5.260000
# mean      5.070714
# std       3.758248
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'GREATER POLAND') min        8.31000
# max       17.83000
# median    11.66500
# mean      12.48377
# std        2.20435
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'HOLY CROSS') min        0.000000
# max       19.950000
# median    12.165000
# mean      12.617857
# std        3.961331
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'KUYAVIA-POMERANIA') min        7.310000
# max       17.930000
# median    12.410000
# mean      12.313571
# std        2.782870
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'LESSER POLAND') min        6.950000
# max       19.870000
# median    11.075000
# mean      12.325437
# std        3.605084
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'LOWER SILESIA') min        0.000000
# max       20.940000
# median    12.090000
# mean      12.620437
# std        3.547867
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'LUBLIN') min        6.570000
# max       15.460000
# median    10.960000
# mean      11.017024
# std        2.326966
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'LUBUSZ') min        0.000000
# max       19.390000
# median    12.575000
# mean      13.144524
# std        3.508056
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'MASOVIA') min        7.840000
# max       20.240000
# median    13.400000
# mean      13.751587
# std        3.073582
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'OPOLE') min        0.000000
# max       19.850000
# median    13.755000
# mean      13.290119
# std        4.776633
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'PODLASKIE') min        7.760000
# max       18.440000
# median    13.525000
# mean      13.753690
# std        2.749418
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'POLAND') min        8.280000
# max       19.060000
# median    12.390000
# mean      13.036627
# std        2.740357
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'POMERANIA') min        8.230000
# max       19.040000
# median    12.590000
# mean      13.145278
# std        3.054755
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'SILESIA') min        7.890000
# max       20.230000
# median    11.750000
# mean      12.676667
# std        3.132381
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'SUBCARPATHIA') min        8.100000
# max       19.300000
# median    12.385000
# mean      13.368333
# std        3.092614
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'WARMIA-MASURIA') min        8.030000
# max       20.900000
# median    12.990000
# mean      13.595238
# std        3.378267
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'WEST POMERANIA') min        8.940000
# max       16.610000
# median    12.975000
# mean      13.142857
# std        1.714551
# Name: value, dtype: float64
# ('smoked bacon with ribs - per 1kg', 'ŁÓDŹ') min        7.160000
# max       18.860000
# median    12.945000
# mean      13.132103
# std        2.493109
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'GREATER POLAND') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'HOLY CROSS') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'KUYAVIA-POMERANIA') min       0.110000
# max       0.500000
# median    0.330000
# mean      0.342460
# std       0.064397
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'LESSER POLAND') min       0.070000
# max       0.570000
# median    0.400000
# mean      0.392143
# std       0.084802
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'LOWER SILESIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'LUBLIN') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'LUBUSZ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'MASOVIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'OPOLE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'PODLASKIE') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'POLAND') min       0.250000
# max       0.540000
# median    0.360000
# mean      0.354802
# std       0.060690
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'POMERANIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'SILESIA') min       0.000000
# max       0.480000
# median    0.300000
# mean      0.246071
# std       0.162978
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'SUBCARPATHIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'WARMIA-MASURIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'WEST POMERANIA') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('white table salt bagged - per 1kg', 'ŁÓDŹ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'GREATER POLAND') min       0.000000
# max       4.070000
# median    2.870000
# mean      2.504841
# std       1.087176
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'HOLY CROSS') min       0.000000
# max       3.460000
# median    0.000000
# mean      0.780516
# std       1.147009
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'KUYAVIA-POMERANIA') min       0.000000
# max       4.830000
# median    2.740000
# mean      2.853810
# std       0.919469
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'LESSER POLAND') min       1.910000
# max       4.570000
# median    3.055000
# mean      3.109683
# std       0.628192
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'LOWER SILESIA') min       0.000000
# max       3.920000
# median    2.560000
# mean      1.924643
# std       1.531573
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'LUBLIN') min       0.000000
# max       3.540000
# median    1.955000
# mean      1.615476
# std       1.329268
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'LUBUSZ') min       0.0
# max       0.0
# median    0.0
# mean      0.0
# std       0.0
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'MASOVIA') min       0.000000
# max       5.060000
# median    3.565000
# mean      3.300992
# std       1.110467
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'OPOLE') min       0.000000
# max       1.990000
# median    0.000000
# mean      0.044762
# std       0.245799
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'PODLASKIE') min       0.000000
# max       3.470000
# median    0.000000
# mean      1.091468
# std       1.279594
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'POLAND') min       1.940000
# max       3.520000
# median    2.880000
# mean      2.828690
# std       0.375319
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'POMERANIA') min       0.000000
# max       6.920000
# median    3.230000
# mean      3.320317
# std       1.833588
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'SILESIA') min       0.380000
# max       3.370000
# median    2.725000
# mean      2.673452
# std       0.440439
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'SUBCARPATHIA') min       1.720000
# max       3.920000
# median    2.575000
# mean      2.689405
# std       0.481247
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'WARMIA-MASURIA') min       0.000000
# max       2.110000
# median    0.000000
# mean      0.097262
# std       0.352599
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'WEST POMERANIA') min       0.000000
# max       2.630000
# median    0.000000
# mean      0.408770
# std       0.824889
# Name: value, dtype: float64
# ('whole pickled cucumbers 0.9l - per 1pc.', 'ŁÓDŹ') min       0.000000
# max       3.440000
# median    2.580000
# mean      2.159524
# std       1.155175
# Name: value, dtype: float64

# %%
from IPython.display import display

province_dataframes = {}

for province in df['province'].unique():
    print(province)
    df_province = df[df['province'] == province]
    df_province_agg = df_province.groupby(['product', 'date'])['value'].agg(['min', 'max', 'median', 'mean', 'std'])
    province_dataframes[province] = df_province_agg
    display(df_province_agg)
    
# province_dataframes['SUBCARPATHIA']
# Out:
# SUBCARPATHIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   3.18  3.18    3.18  3.18  NaN
#                                         2019-6   3.72  3.72    3.72  3.72  NaN
#                                         2019-7   3.28  3.28    3.28  3.28  NaN
#                                         2019-8   3.86  3.86    3.86  3.86  NaN
#                                         2019-9   3.44  3.44    3.44  3.44  NaN
#
# [7559 rows x 5 columns]
# ŁÓDŹ
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   6.76  6.76    6.76  6.76  NaN
#                                         1999-10  6.70  6.70    6.70  6.70  NaN
#                                         1999-11  7.25  7.25    7.25  7.25  NaN
#                                         1999-12  6.94  6.94    6.94  6.94  NaN
#                                         1999-2   6.98  6.98    6.98  6.98  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   2.33  2.33    2.33  2.33  NaN
#                                         2019-6   3.32  3.32    3.32  3.32  NaN
#                                         2019-7   2.46  2.46    2.46  2.46  NaN
#                                         2019-8   2.73  2.73    2.73  2.73  NaN
#                                         2019-9   2.67  2.67    2.67  2.67  NaN
#
# [7559 rows x 5 columns]
# KUYAVIA-POMERANIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   6.72  6.72    6.72  6.72  NaN
#                                         1999-10  6.76  6.76    6.76  6.76  NaN
#                                         1999-11  6.55  6.55    6.55  6.55  NaN
#                                         1999-12  6.90  6.90    6.90  6.90  NaN
#                                         1999-2   7.02  7.02    7.02  7.02  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   2.49  2.49    2.49  2.49  NaN
#                                         2019-6   1.89  1.89    1.89  1.89  NaN
#                                         2019-7   2.08  2.08    2.08  2.08  NaN
#                                         2019-8   1.90  1.90    1.90  1.90  NaN
#                                         2019-9   2.35  2.35    2.35  2.35  NaN
#
# [7559 rows x 5 columns]
# LOWER SILESIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   6.01  6.01    6.01  6.01  NaN
#                                         1999-10  5.69  5.69    5.69  5.69  NaN
#                                         1999-11  6.52  6.52    6.52  6.52  NaN
#                                         1999-12  6.35  6.35    6.35  6.35  NaN
#                                         1999-2   5.52  5.52    5.52  5.52  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   2.56  2.56    2.56  2.56  NaN
#                                         2019-6   2.99  2.99    2.99  2.99  NaN
#                                         2019-7   2.56  2.56    2.56  2.56  NaN
#                                         2019-8   3.52  3.52    3.52  3.52  NaN
#                                         2019-9   3.06  3.06    3.06  3.06  NaN
#
# [7559 rows x 5 columns]
# WARMIA-MASURIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   1.32  1.32    1.32  1.32  NaN
#                                         2019-6   1.67  1.67    1.67  1.67  NaN
#                                         2019-7   1.36  1.36    1.36  1.36  NaN
#                                         2019-8   1.46  1.46    1.46  1.46  NaN
#                                         2019-9   1.22  1.22    1.22  1.22  NaN
#
# [7559 rows x 5 columns]
# HOLY CROSS
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   3.81  3.81    3.81  3.81  NaN
#                                         1999-10  1.27  1.27    1.27  1.27  NaN
#                                         1999-11  1.62  1.62    1.62  1.62  NaN
#                                         1999-12  0.95  0.95    0.95  0.95  NaN
#                                         1999-2   2.67  2.67    2.67  2.67  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   0.06  0.06    0.06  0.06  NaN
#                                         2019-6   0.88  0.88    0.88  0.88  NaN
#                                         2019-7   0.03  0.03    0.03  0.03  NaN
#                                         2019-8   1.55  1.55    1.55  1.55  NaN
#                                         2019-9   1.40  1.40    1.40  1.40  NaN
#
# [7559 rows x 5 columns]
# WEST POMERANIA
#                                                  min  max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.0  0.0     0.0   0.0  NaN
#                                         1999-10  0.0  0.0     0.0   0.0  NaN
#                                         1999-11  0.0  0.0     0.0   0.0  NaN
#                                         1999-12  0.0  0.0     0.0   0.0  NaN
#                                         1999-2   0.0  0.0     0.0   0.0  NaN
# ...                                              ...  ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   0.0  0.0     0.0   0.0  NaN
#                                         2019-6   0.0  0.0     0.0   0.0  NaN
#                                         2019-7   0.0  0.0     0.0   0.0  NaN
#                                         2019-8   0.0  0.0     0.0   0.0  NaN
#                                         2019-9   0.0  0.0     0.0   0.0  NaN
#
# [7559 rows x 5 columns]
# POLAND
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   6.53  6.53    6.53  6.53  NaN
#                                         1999-10  6.95  6.95    6.95  6.95  NaN
#                                         1999-11  6.70  6.70    6.70  6.70  NaN
#                                         1999-12  5.89  5.89    5.89  5.89  NaN
#                                         1999-2   6.74  6.74    6.74  6.74  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   2.84  2.84    2.84  2.84  NaN
#                                         2019-6   3.04  3.04    3.04  3.04  NaN
#                                         2019-7   3.03  3.03    3.03  3.03  NaN
#                                         2019-8   3.02  3.02    3.02  3.02  NaN
#                                         2019-9   3.42  3.42    3.42  3.42  NaN
#
# [7559 rows x 5 columns]
# PODLASKIE
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   1.32  1.32    1.32  1.32  NaN
#                                         2019-6   1.27  1.27    1.27  1.27  NaN
#                                         2019-7   0.78  0.78    0.78  0.78  NaN
#                                         2019-8   1.52  1.52    1.52  1.52  NaN
#                                         2019-9   1.94  1.94    1.94  1.94  NaN
#
# [7559 rows x 5 columns]
# GREATER POLAND
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   7.56  7.56    7.56  7.56  NaN
#                                         1999-10  7.02  7.02    7.02  7.02  NaN
#                                         1999-11  8.21  8.21    8.21  8.21  NaN
#                                         1999-12  7.87  7.87    7.87  7.87  NaN
#                                         1999-2   7.09  7.09    7.09  7.09  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   2.89  2.89    2.89  2.89  NaN
#                                         2019-6   3.48  3.48    3.48  3.48  NaN
#                                         2019-7   2.76  2.76    2.76  2.76  NaN
#                                         2019-8   2.42  2.42    2.42  2.42  NaN
#                                         2019-9   3.46  3.46    3.46  3.46  NaN
#
# [7559 rows x 5 columns]
# POMERANIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   8.03  8.03    8.03  8.03  NaN
#                                         1999-10  7.46  7.46    7.46  7.46  NaN
#                                         1999-11  7.70  7.70    7.70  7.70  NaN
#                                         1999-12  7.57  7.57    7.57  7.57  NaN
#                                         1999-2   7.60  7.60    7.60  7.60  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   4.83  4.83    4.83  4.83  NaN
#                                         2019-6   5.37  5.37    5.37  5.37  NaN
#                                         2019-7   2.33  2.33    2.33  2.33  NaN
#                                         2019-8   3.55  3.55    3.55  3.55  NaN
#                                         2019-9   2.36  2.36    2.36  2.36  NaN
#
# [7559 rows x 5 columns]
# LESSER POLAND
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   6.23  6.23    6.23  6.23  NaN
#                                         1999-10  4.39  4.39    4.39  4.39  NaN
#                                         1999-11  3.76  3.76    3.76  3.76  NaN
#                                         1999-12  1.58  1.58    1.58  1.58  NaN
#                                         1999-2   4.35  4.35    4.35  4.35  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   3.56  3.56    3.56  3.56  NaN
#                                         2019-6   2.60  2.60    2.60  2.60  NaN
#                                         2019-7   2.80  2.80    2.80  2.80  NaN
#                                         2019-8   3.92  3.92    3.92  3.92  NaN
#                                         2019-9   3.96  3.96    3.96  3.96  NaN
#
# [7559 rows x 5 columns]
# SILESIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   7.10  7.10    7.10  7.10  NaN
#                                         1999-10  7.43  7.43    7.43  7.43  NaN
#                                         1999-11  7.32  7.32    7.32  7.32  NaN
#                                         1999-12  7.49  7.49    7.49  7.49  NaN
#                                         1999-2   7.73  7.73    7.73  7.73  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   3.30  3.30    3.30  3.30  NaN
#                                         2019-6   0.66  0.66    0.66  0.66  NaN
#                                         2019-7   1.12  1.12    1.12  1.12  NaN
#                                         2019-8   2.81  2.81    2.81  2.81  NaN
#                                         2019-9   1.97  1.97    1.97  1.97  NaN
#
# [7559 rows x 5 columns]
# MASOVIA
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   4.13  4.13    4.13  4.13  NaN
#                                         2019-6   1.76  1.76    1.76  1.76  NaN
#                                         2019-7   3.76  3.76    3.76  3.76  NaN
#                                         2019-8   1.36  1.36    1.36  1.36  NaN
#                                         2019-9   3.11  3.11    3.11  3.11  NaN
#
# [7559 rows x 5 columns]
# LUBLIN
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   1.52  1.52    1.52  1.52  NaN
#                                         2019-6   1.96  1.96    1.96  1.96  NaN
#                                         2019-7   2.00  2.00    2.00  2.00  NaN
#                                         2019-8   1.60  1.60    1.60  1.60  NaN
#                                         2019-9   1.74  1.74    1.74  1.74  NaN
#
# [7559 rows x 5 columns]
# LUBUSZ
#                                                  min  max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.0  0.0     0.0   0.0  NaN
#                                         1999-10  0.0  0.0     0.0   0.0  NaN
#                                         1999-11  0.0  0.0     0.0   0.0  NaN
#                                         1999-12  0.0  0.0     0.0   0.0  NaN
#                                         1999-2   0.0  0.0     0.0   0.0  NaN
# ...                                              ...  ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   0.0  0.0     0.0   0.0  NaN
#                                         2019-6   0.0  0.0     0.0   0.0  NaN
#                                         2019-7   0.0  0.0     0.0   0.0  NaN
#                                         2019-8   0.0  0.0     0.0   0.0  NaN
#                                         2019-9   0.0  0.0     0.0   0.0  NaN
#
# [7559 rows x 5 columns]
# OPOLE
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   1.99  1.99    1.99  1.99  NaN
#                                         2019-6   1.68  1.68    1.68  1.68  NaN
#                                         2019-7   0.65  0.65    0.65  0.65  NaN
#                                         2019-8   0.61  0.61    0.61  0.61  NaN
#                                         2019-9   0.38  0.38    0.38  0.38  NaN
#
# [7559 rows x 5 columns]

# %%
# Out:
#                                                   min   max  median  mean  std
# product                                 date
# 30% tomato concentrate - per 1kg        1999-1   0.00  0.00    0.00  0.00  NaN
#                                         1999-10  0.00  0.00    0.00  0.00  NaN
#                                         1999-11  0.00  0.00    0.00  0.00  NaN
#                                         1999-12  0.00  0.00    0.00  0.00  NaN
#                                         1999-2   0.00  0.00    0.00  0.00  NaN
# ...                                               ...   ...     ...   ...  ...
# whole pickled cucumbers 0.9l - per 1pc. 2019-5   3.18  3.18    3.18  3.18  NaN
#                                         2019-6   3.72  3.72    3.72  3.72  NaN
#                                         2019-7   3.28  3.28    3.28  3.28  NaN
#                                         2019-8   3.86  3.86    3.86  3.86  NaN
#                                         2019-9   3.44  3.44    3.44  3.44  NaN
#
# [7559 rows x 5 columns]
