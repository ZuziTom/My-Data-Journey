# %% [markdown]
# Based on the data from file `Meteo data.csv`, create a plot showing the average daily relative humidity in Warsaw in 2020.
#
# The plot should meet the following requirements:
# 1. The x-axis should be labeled with months.
# 2. Both x-axis and y-axis should have appropriate descriptions.
# 3. The plot should include a title.
# 4. The plot should include a legend.
# 5. The line of the plot should be red, continuous.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('../01_Data for plots/Meteo data.csv', sep=';', decimal='.')

plt.figure(figsize=(15,10))
plt.plot(df['Average daily relative humidity'],'r', label='Daily humidity')
# plt.plot(months_change, df_month_avg['Average relative humidity'], '-.y', label='Average humidity', drawstyle='steps-post')
plt.xticks(ticks=months_change, labels=months_names, rotation=45)
plt.ylabel('Humidity')
plt.xlabel('Months')
plt.title("Temperature humidity in Poland in 2020")
plt.legend(loc = 'right')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv('../01_Data for plots/Meteo data.csv', sep=';', decimal='.')

# Calculating the average daily relative humidity for each month

monthly_avg_humidity = Meteo_data.groupby('Month')['Average dailu relative himidity'].mean

# Setting the x-axis labels to months
months_names = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']

# Creating the plot without using mdates or numpy
plt.figure(figsize=(10, 6))
plt.plot(monthly_avg_humidity, 'ro-', label='Relative Humidity')
plt.xticks(range(1, 13), months_names)

# Adding labels and title
plt.xlabel('Month')
plt.ylabel('Average Daily Relative Humidity (%)')
plt.title('Average Daily Relative Humidity in Warsaw (2020)')
plt.legend()

# Improving layout
plt.grid()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       5 df = pd.read_csv('../01_Data for plots/Meteo data.csv', sep=';', decimal='.')
#       7 # Calculating the average daily relative humidity for each month
# ----> 9 monthly_avg_humidity = Meteo_data.groupby('Month')['Average dailu relative himidity'].mean
#      11 # Setting the x-axis labels to months
#      12 months_names = ['January', 'February', 'March', 'April', 'May', 'June',
#      13                 'July', 'August', 'September', 'October', 'November', 'December']
#
# NameError: name 'Meteo_data' is not defined
